# %% [markdown]
# <a href="https://colab.research.google.com/github/ga642381/ML2021-Spring/blob/main/HW01/HW01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework 1: COVID-19 Cases Prediction (Regression)**

# %% [markdown]
# Objectives:
# * Solve a regression problem with deep neural networks (DNN).
# * Understand basic DNN training tips.
# * Get familiar with PyTorch.

# %% [markdown]
# # **Download Data**

# %%
tr_path = 'covid.train.csv'  # path to training data
tt_path = 'covid.test.csv'   # path to testing data

# !gdown --id '19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF' --output covid.train.csv
# !gdown --id '1CE240jLm2npU-tdz81-oVKEF3T2yfT1O' --output covid.test.csv
# Out:
# /bin/bash: 行 1: gdown: 未找到命令
# /bin/bash: 行 1: gdown: 未找到命令

# %% [markdown]
# # **Import Some Packages**

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 42069  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# # **Some Utilities**
#
# You do not need to modify this part.

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 2.)
    plt.xlabel('Training steps')
    plt.ylabel('loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()


def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# # **Preprocess**
#
# We have three kinds of datasets:
# * `train`: for training
# * `dev`: for validation
# * `test`: for testing (w/o target value)

# %% [markdown]
# ## **Dataset**
#
# The `COVID19Dataset` below does:
# * read `.csv` files
# * extract features
# * split `covid.train.csv` into train/dev sets
# * normalize features
#
# Finishing `TODO` below might make you pass medium baseline.

# %%
class COVID19Dataset(Dataset):
    ''' Dataset for loading and preprocessing the COVID19 dataset '''
    def __init__(self,
                 path,
                 mode='train',
                 target_only=False):
        self.mode = mode

        # Read data into numpy arrays
        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)

        if not target_only:
            feats = list(range(93))
        else:
            # TODO: Using 40 states & 2 tested_positive features (indices = 57 & 75)
            pass

        if mode == 'test':
            # Testing data
            # data: 893 x 93 (40 states + day 1 (18) + day 2 (18) + day 3 (17))
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training data (train/dev sets)
            # data: 2700 x 94 (40 states + day 1 (18) + day 2 (18) + day 3 (18))
            target = data[:, -1]
            data = data[:, feats]

            # Splitting training data into train & dev sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]

            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features (you may remove this part to see what will happen)
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing (no target)
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %% [markdown]
# ## **DataLoader**
#
# A `DataLoader` loads data from a given `Dataset` into batches.

# %%
def prep_dataloader(path, mode, batch_size, n_jobs=0, target_only=False):
    ''' Generates a dataset, then is put into a dataloader. '''
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)  # Construct dataset
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)                            # Construct dataloader
    return dataloader

# %% [markdown]
# # **Deep Neural Network**
#
# `NeuralNet` is an `nn.Module` designed for regression.
# The DNN consists of 2 fully-connected layers with ReLU activation.
# This module also included a function `cal_loss` for calculating loss.

# %%
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()

        # Define your neural network here
        # TODO: How to modify this model to achieve better performance?
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),   # 扩宽第一层神经元数量
            nn.ReLU(),
            nn.Linear(64, 32), 
            nn.ReLU(),
            nn.Linear(32, 1)
        )

        # Mean squared error loss
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
        ''' Calculate loss with L2 regularization '''
        loss = self.criterion(pred, target)
        l2_reg = 0
        for param in self.parameters():
            l2_reg += torch.norm(param, p=2)
        loss += 5.0 * 1e-4 * l2_reg  # 添加 L2 正则化项
        return loss

# %% [markdown]
# # **Train/Dev/Test**

# %% [markdown]
# ## **Training**

# %%
def train(tr_set, dv_set, model, config, device):
    ''' DNN training '''

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        # After each epoch, test your model on the validation (development) set.
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            # Stop training if your model stops improving for "config['early_stop']" epochs.
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# ## **Validation**

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# ## **Testing**

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# # **Setup Hyper-parameters**
#
# `config` contains hyper-parameters for training and the path to save your model.

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
target_only = False                   # TODO: Using 40 states & 2 tested_positive features

# TODO: How to tune these hyper-parameters to improve your model's performance?
config = {
    'n_epochs': 3000,
    'batch_size': 250,
    'optimizer': 'Adam',               # 换用 Adam 优化器
    'optim_hparas': {'lr': 0.0002},     # 学习率
    'early_stop': 100,                 # 提前停止的 patience 调低
    'save_path': 'models/model.pth'
}

# %% [markdown]
# # **Load data and model**

# %%
tr_set = prep_dataloader(tr_path, 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataloader(tr_path, 'dev', config['batch_size'], target_only=target_only)
tt_set = prep_dataloader(tt_path, 'test', config['batch_size'], target_only=target_only)
# Out:
# Finished reading the train set of COVID19 Dataset (2430 samples found, each dim = 93)
# Finished reading the dev set of COVID19 Dataset (270 samples found, each dim = 93)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 93)

# %%
model = NeuralNet(tr_set.dataset.dim).to(device)  # Construct model and move to device

# %% [markdown]
# # **Start Training!**

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 329.8880)
# Saving model (epoch =    2, loss = 327.2869)
# Saving model (epoch =    3, loss = 324.5306)
# Saving model (epoch =    4, loss = 321.2660)
# Saving model (epoch =    5, loss = 317.1414)
# Saving model (epoch =    6, loss = 311.9358)
# Saving model (epoch =    7, loss = 305.4383)
# Saving model (epoch =    8, loss = 297.1180)
# Saving model (epoch =    9, loss = 286.7079)
# Saving model (epoch =   10, loss = 273.5809)
# Saving model (epoch =   11, loss = 257.6849)
# Saving model (epoch =   12, loss = 239.3086)
# Saving model (epoch =   13, loss = 218.6506)
# Saving model (epoch =   14, loss = 196.2728)
# Saving model (epoch =   15, loss = 172.7709)
# Saving model (epoch =   16, loss = 149.0506)
# Saving model (epoch =   17, loss = 126.2463)
# Saving model (epoch =   18, loss = 105.2217)
# Saving model (epoch =   19, loss = 86.8093)
# Saving model (epoch =   20, loss = 71.7983)
# Saving model (epoch =   21, loss = 60.1539)
# Saving model (epoch =   22, loss = 51.7604)
# Saving model (epoch =   23, loss = 45.7049)
# Saving model (epoch =   24, loss = 41.6290)
# Saving model (epoch =   25, loss = 38.7742)
# Saving model (epoch =   26, loss = 36.7418)
# Saving model (epoch =   27, loss = 35.1250)
# Saving model (epoch =   28, loss = 33.9004)
# Saving model (epoch =   29, loss = 32.8117)
# Saving model (epoch =   30, loss = 31.9155)
# Saving model (epoch =   31, loss = 31.1659)
# Saving model (epoch =   32, loss = 30.4558)
# Saving model (epoch =   33, loss = 29.8240)
# Saving model (epoch =   34, loss = 29.2226)
# Saving model (epoch =   35, loss = 28.6723)
# Saving model (epoch =   36, loss = 28.1490)
# Saving model (epoch =   37, loss = 27.6560)
# Saving model (epoch =   38, loss = 27.1498)
# Saving model (epoch =   39, loss = 26.6680)
# Saving model (epoch =   40, loss = 26.1992)
# Saving model (epoch =   41, loss = 25.7246)
# Saving model (epoch =   42, loss = 25.2805)
# Saving model (epoch =   43, loss = 24.8331)
# Saving model (epoch =   44, loss = 24.4003)
# Saving model (epoch =   45, loss = 23.9730)
# Saving model (epoch =   46, loss = 23.5373)
# Saving model (epoch =   47, loss = 23.1215)
# Saving model (epoch =   48, loss = 22.7211)
# Saving model (epoch =   49, loss = 22.3239)
# Saving model (epoch =   50, loss = 21.9093)
# Saving model (epoch =   51, loss = 21.4837)
# Saving model (epoch =   52, loss = 21.0788)
# Saving model (epoch =   53, loss = 20.6757)
# Saving model (epoch =   54, loss = 20.2594)
# Saving model (epoch =   55, loss = 19.8448)
# Saving model (epoch =   56, loss = 19.4587)
# Saving model (epoch =   57, loss = 19.0682)
# Saving model (epoch =   58, loss = 18.6677)
# Saving model (epoch =   59, loss = 18.2718)
# Saving model (epoch =   60, loss = 17.8967)
# Saving model (epoch =   61, loss = 17.5353)
# Saving model (epoch =   62, loss = 17.1860)
# Saving model (epoch =   63, loss = 16.8317)
# Saving model (epoch =   64, loss = 16.4728)
# Saving model (epoch =   65, loss = 16.1228)
# Saving model (epoch =   66, loss = 15.7765)
# Saving model (epoch =   67, loss = 15.4468)
# Saving model (epoch =   68, loss = 15.1435)
# Saving model (epoch =   69, loss = 14.7955)
# Saving model (epoch =   70, loss = 14.4722)
# Saving model (epoch =   71, loss = 14.1755)
# Saving model (epoch =   72, loss = 13.8704)
# Saving model (epoch =   73, loss = 13.5817)
# Saving model (epoch =   74, loss = 13.2809)
# Saving model (epoch =   75, loss = 12.9976)
# Saving model (epoch =   76, loss = 12.7219)
# Saving model (epoch =   77, loss = 12.4542)
# Saving model (epoch =   78, loss = 12.2027)
# Saving model (epoch =   79, loss = 11.9397)
# Saving model (epoch =   80, loss = 11.6859)
# Saving model (epoch =   81, loss = 11.4411)
# Saving model (epoch =   82, loss = 11.1941)
# Saving model (epoch =   83, loss = 10.9458)
# Saving model (epoch =   84, loss = 10.7114)
# Saving model (epoch =   85, loss = 10.4694)
# Saving model (epoch =   86, loss = 10.2381)
# Saving model (epoch =   87, loss = 10.0190)
# Saving model (epoch =   88, loss = 9.7997)
# Saving model (epoch =   89, loss = 9.5815)
# Saving model (epoch =   90, loss = 9.3801)
# Saving model (epoch =   91, loss = 9.1833)
# Saving model (epoch =   92, loss = 8.9894)
# Saving model (epoch =   93, loss = 8.7959)
# Saving model (epoch =   94, loss = 8.6003)
# Saving model (epoch =   95, loss = 8.4145)
# Saving model (epoch =   96, loss = 8.2405)
# Saving model (epoch =   97, loss = 8.0543)
# Saving model (epoch =   98, loss = 7.8828)
# Saving model (epoch =   99, loss = 7.7262)
# Saving model (epoch =  100, loss = 7.5587)
# Saving model (epoch =  101, loss = 7.4004)
# Saving model (epoch =  102, loss = 7.2494)
# Saving model (epoch =  103, loss = 7.1000)
# Saving model (epoch =  104, loss = 6.9570)
# Saving model (epoch =  105, loss = 6.8035)
# Saving model (epoch =  106, loss = 6.6576)
# Saving model (epoch =  107, loss = 6.5254)
# Saving model (epoch =  108, loss = 6.3953)
# Saving model (epoch =  109, loss = 6.2727)
# Saving model (epoch =  110, loss = 6.1361)
# Saving model (epoch =  111, loss = 6.0115)
# Saving model (epoch =  112, loss = 5.8923)
# Saving model (epoch =  113, loss = 5.7797)
# Saving model (epoch =  114, loss = 5.6663)
# Saving model (epoch =  115, loss = 5.5575)
# Saving model (epoch =  116, loss = 5.4394)
# Saving model (epoch =  117, loss = 5.3353)
# Saving model (epoch =  118, loss = 5.2315)
# Saving model (epoch =  119, loss = 5.1320)
# Saving model (epoch =  120, loss = 5.0271)
# Saving model (epoch =  121, loss = 4.9309)
# Saving model (epoch =  122, loss = 4.8382)
# Saving model (epoch =  123, loss = 4.7529)
# Saving model (epoch =  124, loss = 4.6596)
# Saving model (epoch =  125, loss = 4.5748)
# Saving model (epoch =  126, loss = 4.4841)
# Saving model (epoch =  127, loss = 4.4057)
# Saving model (epoch =  128, loss = 4.3291)
# Saving model (epoch =  129, loss = 4.2583)
# Saving model (epoch =  130, loss = 4.1948)
# Saving model (epoch =  131, loss = 4.1211)
# Saving model (epoch =  132, loss = 4.0556)
# Saving model (epoch =  133, loss = 3.9885)
# Saving model (epoch =  134, loss = 3.9287)
# Saving model (epoch =  135, loss = 3.8689)
# Saving model (epoch =  136, loss = 3.8125)
# Saving model (epoch =  137, loss = 3.7559)
# Saving model (epoch =  138, loss = 3.7096)
# Saving model (epoch =  139, loss = 3.6573)
# Saving model (epoch =  140, loss = 3.6096)
# Saving model (epoch =  141, loss = 3.5566)
# Saving model (epoch =  142, loss = 3.5040)
# Saving model (epoch =  143, loss = 3.4583)
# Saving model (epoch =  144, loss = 3.4153)
# Saving model (epoch =  145, loss = 3.3690)
# Saving model (epoch =  146, loss = 3.3273)
# Saving model (epoch =  147, loss = 3.2929)
# Saving model (epoch =  148, loss = 3.2493)
# Saving model (epoch =  149, loss = 3.2098)
# Saving model (epoch =  150, loss = 3.1762)
# Saving model (epoch =  151, loss = 3.1460)
# Saving model (epoch =  152, loss = 3.1028)
# Saving model (epoch =  153, loss = 3.0682)
# Saving model (epoch =  154, loss = 3.0401)
# Saving model (epoch =  155, loss = 3.0123)
# Saving model (epoch =  156, loss = 2.9875)
# Saving model (epoch =  157, loss = 2.9653)
# Saving model (epoch =  158, loss = 2.9445)
# Saving model (epoch =  159, loss = 2.9062)
# Saving model (epoch =  160, loss = 2.8836)
# Saving model (epoch =  161, loss = 2.8631)
# Saving model (epoch =  162, loss = 2.8369)
# Saving model (epoch =  163, loss = 2.8189)
# Saving model (epoch =  164, loss = 2.7951)
# Saving model (epoch =  165, loss = 2.7738)
# Saving model (epoch =  166, loss = 2.7565)
# Saving model (epoch =  167, loss = 2.7302)
# Saving model (epoch =  168, loss = 2.7051)
# Saving model (epoch =  169, loss = 2.6809)
# Saving model (epoch =  170, loss = 2.6648)
# Saving model (epoch =  171, loss = 2.6502)
# Saving model (epoch =  172, loss = 2.6227)
# Saving model (epoch =  173, loss = 2.6064)
# Saving model (epoch =  174, loss = 2.5990)
# Saving model (epoch =  175, loss = 2.5745)
# Saving model (epoch =  176, loss = 2.5532)
# Saving model (epoch =  177, loss = 2.5529)
# Saving model (epoch =  178, loss = 2.5261)
# Saving model (epoch =  179, loss = 2.5025)
# Saving model (epoch =  180, loss = 2.4822)
# Saving model (epoch =  181, loss = 2.4695)
# Saving model (epoch =  182, loss = 2.4522)
# Saving model (epoch =  183, loss = 2.4461)
# Saving model (epoch =  184, loss = 2.4304)
# Saving model (epoch =  185, loss = 2.4164)
# Saving model (epoch =  186, loss = 2.3991)
# Saving model (epoch =  187, loss = 2.3761)
# Saving model (epoch =  188, loss = 2.3666)
# Saving model (epoch =  189, loss = 2.3533)
# Saving model (epoch =  190, loss = 2.3417)
# Saving model (epoch =  191, loss = 2.3200)
# Saving model (epoch =  192, loss = 2.3100)
# Saving model (epoch =  193, loss = 2.2954)
# Saving model (epoch =  194, loss = 2.2751)
# Saving model (epoch =  195, loss = 2.2737)
# Saving model (epoch =  197, loss = 2.2597)
# Saving model (epoch =  198, loss = 2.2345)
# Saving model (epoch =  199, loss = 2.2195)
# Saving model (epoch =  200, loss = 2.2086)
# Saving model (epoch =  201, loss = 2.1977)
# Saving model (epoch =  202, loss = 2.1863)
# Saving model (epoch =  203, loss = 2.1812)
# Saving model (epoch =  204, loss = 2.1716)
# Saving model (epoch =  205, loss = 2.1483)
# Saving model (epoch =  206, loss = 2.1351)
# Saving model (epoch =  207, loss = 2.1205)
# Saving model (epoch =  208, loss = 2.1167)
# Saving model (epoch =  209, loss = 2.1023)
# Saving model (epoch =  210, loss = 2.0890)
# Saving model (epoch =  211, loss = 2.0748)
# Saving model (epoch =  212, loss = 2.0693)
# Saving model (epoch =  213, loss = 2.0564)
# Saving model (epoch =  214, loss = 2.0407)
# Saving model (epoch =  216, loss = 2.0195)
# Saving model (epoch =  217, loss = 2.0071)
# Saving model (epoch =  218, loss = 2.0068)
# Saving model (epoch =  219, loss = 1.9948)
# Saving model (epoch =  220, loss = 1.9682)
# Saving model (epoch =  221, loss = 1.9597)
# Saving model (epoch =  222, loss = 1.9483)
# Saving model (epoch =  223, loss = 1.9413)
# Saving model (epoch =  224, loss = 1.9376)
# Saving model (epoch =  226, loss = 1.9202)
# Saving model (epoch =  227, loss = 1.9142)
# Saving model (epoch =  228, loss = 1.9006)
# Saving model (epoch =  229, loss = 1.8958)
# Saving model (epoch =  230, loss = 1.8843)
# Saving model (epoch =  231, loss = 1.8824)
# Saving model (epoch =  232, loss = 1.8781)
# Saving model (epoch =  233, loss = 1.8649)
# Saving model (epoch =  234, loss = 1.8526)
# Saving model (epoch =  235, loss = 1.8396)
# Saving model (epoch =  236, loss = 1.8302)
# Saving model (epoch =  237, loss = 1.8279)
# Saving model (epoch =  238, loss = 1.8231)
# Saving model (epoch =  239, loss = 1.8144)
# Saving model (epoch =  240, loss = 1.8110)
# Saving model (epoch =  241, loss = 1.8087)
# Saving model (epoch =  242, loss = 1.7926)
# Saving model (epoch =  243, loss = 1.7771)
# Saving model (epoch =  244, loss = 1.7690)
# Saving model (epoch =  246, loss = 1.7576)
# Saving model (epoch =  247, loss = 1.7546)
# Saving model (epoch =  248, loss = 1.7444)
# Saving model (epoch =  250, loss = 1.7384)
# Saving model (epoch =  251, loss = 1.7231)
# Saving model (epoch =  253, loss = 1.7225)
# Saving model (epoch =  254, loss = 1.7162)
# Saving model (epoch =  255, loss = 1.7034)
# Saving model (epoch =  256, loss = 1.6977)
# Saving model (epoch =  257, loss = 1.6856)
# Saving model (epoch =  258, loss = 1.6784)
# Saving model (epoch =  259, loss = 1.6737)
# Saving model (epoch =  260, loss = 1.6650)
# Saving model (epoch =  261, loss = 1.6539)
# Saving model (epoch =  264, loss = 1.6433)
# Saving model (epoch =  265, loss = 1.6368)
# Saving model (epoch =  267, loss = 1.6277)
# Saving model (epoch =  268, loss = 1.6216)
# Saving model (epoch =  269, loss = 1.6093)
# Saving model (epoch =  270, loss = 1.6080)
# Saving model (epoch =  271, loss = 1.5966)
# Saving model (epoch =  272, loss = 1.5834)
# Saving model (epoch =  273, loss = 1.5818)
# Saving model (epoch =  275, loss = 1.5767)
# Saving model (epoch =  276, loss = 1.5760)
# Saving model (epoch =  277, loss = 1.5685)
# Saving model (epoch =  278, loss = 1.5653)
# Saving model (epoch =  279, loss = 1.5574)
# Saving model (epoch =  280, loss = 1.5533)
# Saving model (epoch =  281, loss = 1.5457)
# Saving model (epoch =  283, loss = 1.5447)
# Saving model (epoch =  284, loss = 1.5291)
# Saving model (epoch =  286, loss = 1.5231)
# Saving model (epoch =  287, loss = 1.5185)
# Saving model (epoch =  288, loss = 1.5173)
# Saving model (epoch =  290, loss = 1.5049)
# Saving model (epoch =  291, loss = 1.5026)
# Saving model (epoch =  292, loss = 1.4986)
# Saving model (epoch =  293, loss = 1.4980)
# Saving model (epoch =  294, loss = 1.4884)
# Saving model (epoch =  295, loss = 1.4831)
# Saving model (epoch =  296, loss = 1.4810)
# Saving model (epoch =  297, loss = 1.4672)
# Saving model (epoch =  298, loss = 1.4638)
# Saving model (epoch =  299, loss = 1.4635)
# Saving model (epoch =  302, loss = 1.4625)
# Saving model (epoch =  303, loss = 1.4553)
# Saving model (epoch =  304, loss = 1.4514)
# Saving model (epoch =  305, loss = 1.4412)
# Saving model (epoch =  308, loss = 1.4328)
# Saving model (epoch =  309, loss = 1.4253)
# Saving model (epoch =  311, loss = 1.4230)
# Saving model (epoch =  313, loss = 1.4130)
# Saving model (epoch =  315, loss = 1.4118)
# Saving model (epoch =  317, loss = 1.4068)
# Saving model (epoch =  318, loss = 1.4044)
# Saving model (epoch =  319, loss = 1.3923)
# Saving model (epoch =  320, loss = 1.3914)
# Saving model (epoch =  321, loss = 1.3896)
# Saving model (epoch =  324, loss = 1.3800)
# Saving model (epoch =  327, loss = 1.3727)
# Saving model (epoch =  329, loss = 1.3535)
# Saving model (epoch =  332, loss = 1.3500)
# Saving model (epoch =  334, loss = 1.3499)
# Saving model (epoch =  335, loss = 1.3397)
# Saving model (epoch =  336, loss = 1.3381)
# Saving model (epoch =  337, loss = 1.3379)
# Saving model (epoch =  338, loss = 1.3228)
# Saving model (epoch =  340, loss = 1.3182)
# Saving model (epoch =  344, loss = 1.3179)
# Saving model (epoch =  346, loss = 1.3114)
# Saving model (epoch =  348, loss = 1.2945)
# Saving model (epoch =  351, loss = 1.2928)
# Saving model (epoch =  352, loss = 1.2927)
# Saving model (epoch =  354, loss = 1.2910)
# Saving model (epoch =  355, loss = 1.2737)
# Saving model (epoch =  357, loss = 1.2661)
# Saving model (epoch =  360, loss = 1.2603)
# Saving model (epoch =  361, loss = 1.2560)
# Saving model (epoch =  363, loss = 1.2490)
# Saving model (epoch =  365, loss = 1.2355)
# Saving model (epoch =  368, loss = 1.2338)
# Saving model (epoch =  370, loss = 1.2261)
# Saving model (epoch =  371, loss = 1.2232)
# Saving model (epoch =  372, loss = 1.2187)
# Saving model (epoch =  375, loss = 1.2096)
# Saving model (epoch =  377, loss = 1.2005)
# Saving model (epoch =  382, loss = 1.1961)
# Saving model (epoch =  384, loss = 1.1939)
# Saving model (epoch =  385, loss = 1.1871)
# Saving model (epoch =  387, loss = 1.1741)
# Saving model (epoch =  390, loss = 1.1728)
# Saving model (epoch =  394, loss = 1.1641)
# Saving model (epoch =  397, loss = 1.1592)
# Saving model (epoch =  398, loss = 1.1562)
# Saving model (epoch =  399, loss = 1.1468)
# Saving model (epoch =  403, loss = 1.1420)
# Saving model (epoch =  405, loss = 1.1386)
# Saving model (epoch =  406, loss = 1.1353)
# Saving model (epoch =  407, loss = 1.1350)
# Saving model (epoch =  410, loss = 1.1309)
# Saving model (epoch =  412, loss = 1.1282)
# Saving model (epoch =  413, loss = 1.1230)
# Saving model (epoch =  415, loss = 1.1206)
# Saving model (epoch =  417, loss = 1.1127)
# Saving model (epoch =  419, loss = 1.1078)
# Saving model (epoch =  420, loss = 1.1074)
# Saving model (epoch =  423, loss = 1.1050)
# Saving model (epoch =  425, loss = 1.1044)
# Saving model (epoch =  427, loss = 1.0959)
# Saving model (epoch =  429, loss = 1.0878)
# Saving model (epoch =  437, loss = 1.0878)
# Saving model (epoch =  438, loss = 1.0865)
# Saving model (epoch =  439, loss = 1.0727)
# Saving model (epoch =  440, loss = 1.0717)
# Saving model (epoch =  446, loss = 1.0609)
# Saving model (epoch =  449, loss = 1.0559)
# Saving model (epoch =  454, loss = 1.0511)
# Saving model (epoch =  457, loss = 1.0486)
# Saving model (epoch =  458, loss = 1.0394)
# Saving model (epoch =  459, loss = 1.0345)
# Saving model (epoch =  463, loss = 1.0280)
# Saving model (epoch =  470, loss = 1.0276)
# Saving model (epoch =  471, loss = 1.0177)
# Saving model (epoch =  475, loss = 1.0167)
# Saving model (epoch =  476, loss = 1.0157)
# Saving model (epoch =  477, loss = 1.0060)
# Saving model (epoch =  483, loss = 0.9994)
# Saving model (epoch =  486, loss = 0.9992)
# Saving model (epoch =  487, loss = 0.9862)
# Saving model (epoch =  495, loss = 0.9818)
# Saving model (epoch =  499, loss = 0.9741)
# Saving model (epoch =  509, loss = 0.9733)
# Saving model (epoch =  510, loss = 0.9723)
# Saving model (epoch =  512, loss = 0.9684)
# Saving model (epoch =  514, loss = 0.9659)
# Saving model (epoch =  516, loss = 0.9595)
# Saving model (epoch =  525, loss = 0.9521)
# Saving model (epoch =  530, loss = 0.9496)
# Saving model (epoch =  531, loss = 0.9416)
# Saving model (epoch =  532, loss = 0.9371)
# Saving model (epoch =  533, loss = 0.9369)
# Saving model (epoch =  542, loss = 0.9351)
# Saving model (epoch =  546, loss = 0.9286)
# Saving model (epoch =  547, loss = 0.9251)
# Saving model (epoch =  552, loss = 0.9202)
# Saving model (epoch =  562, loss = 0.9189)
# Saving model (epoch =  569, loss = 0.9038)
# Saving model (epoch =  575, loss = 0.8984)
# Saving model (epoch =  579, loss = 0.8974)
# Saving model (epoch =  591, loss = 0.8973)
# Saving model (epoch =  592, loss = 0.8887)
# Saving model (epoch =  601, loss = 0.8859)
# Saving model (epoch =  608, loss = 0.8757)
# Saving model (epoch =  617, loss = 0.8741)
# Saving model (epoch =  619, loss = 0.8730)
# Saving model (epoch =  627, loss = 0.8661)
# Saving model (epoch =  631, loss = 0.8658)
# Saving model (epoch =  632, loss = 0.8638)
# Saving model (epoch =  640, loss = 0.8633)
# Saving model (epoch =  641, loss = 0.8582)
# Saving model (epoch =  644, loss = 0.8561)
# Saving model (epoch =  651, loss = 0.8543)
# Saving model (epoch =  657, loss = 0.8497)
# Saving model (epoch =  668, loss = 0.8443)
# Saving model (epoch =  672, loss = 0.8442)
# Saving model (epoch =  673, loss = 0.8439)
# Saving model (epoch =  679, loss = 0.8429)
# Saving model (epoch =  683, loss = 0.8425)
# Saving model (epoch =  687, loss = 0.8372)
# Saving model (epoch =  694, loss = 0.8345)
# Saving model (epoch =  698, loss = 0.8246)
# Saving model (epoch =  732, loss = 0.8238)
# Saving model (epoch =  745, loss = 0.8158)
# Saving model (epoch =  750, loss = 0.8144)
# Saving model (epoch =  759, loss = 0.8125)
# Saving model (epoch =  767, loss = 0.8074)
# Saving model (epoch =  772, loss = 0.8072)
# Saving model (epoch =  774, loss = 0.8041)
# Saving model (epoch =  800, loss = 0.7985)
# Saving model (epoch =  865, loss = 0.7954)
# Saving model (epoch =  883, loss = 0.7915)
# Saving model (epoch =  888, loss = 0.7897)
# Saving model (epoch =  942, loss = 0.7815)
# Saving model (epoch = 1043, loss = 0.7759)
# Saving model (epoch = 1128, loss = 0.7684)
# Saving model (epoch = 1216, loss = 0.7647)
# Saving model (epoch = 1268, loss = 0.7647)
# Saving model (epoch = 1362, loss = 0.7618)
# Saving model (epoch = 1364, loss = 0.7602)
# Finished training after 1465 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)  # Show prediction on the validation set
# Out:
# /tmp/ipykernel_1273842/1425700501.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model

# %% [markdown]
# TODO:
#
# 1. Observe the influence of hyperparameters on model performance, such as batch size and learning rate (at least these two types of hypterparameters, and choose 3 values for each one). If you plan to use more advanced component, please also report your hyperparameters. To observe training process with different hyperparameters, plot all your training loss and validation loss versus iteration (e.g., such as above figure showed by using *plot_learning_curve* mehtod) under different hyperparameters in one figure.
#
# 2. Save model that obtain the best performance on validation set and wirte the code to report average error. Note that, we use this error to create a leaderboard.

# %% [markdown]
# # **Testing**
# Commonly，after selecting the best model by using validation set, the learned model can be deployed in real world application. The performance can be evluated by testing set. The predictions of your model on testing set will be stored at `pred.csv`.

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'pred.csv')         # save prediction file to pred.csv
# Out:
# Saving results to pred.csv

# %% [markdown]
# # **Hints**
#
# ## **Simple Baseline**
# * Run sample code
#
# ## **Medium Baseline**
# * Feature selection: 40 states + 2 `tested_positive` (`TODO` in dataset)
#
# ## **Strong Baseline**
# * Feature selection (what other features are useful?)
# * DNN architecture (layers? dimension? activation function?)
# * Training (mini-batch? optimizer? learning rate?)
# * L2 regularization
# * There are some mistakes in the sample code, can you find them?

# %% [markdown]
# ## **TODO:**
#
# ---
# 1. Observe the influence of hyperparameters on model performance, such as batch size and learning rate (at least these two types of hypterparameters, and choose 3 values for each one). If you plan to use more advanced component, please also report your hyperparameters. To observe training process with different hyperparameters, **plot all your training loss and validation loss versus iteration (e.g., such as above figure showed by using *plot_learning_curve()* mehtod) under different hyperparameters in one figure.**
#
# ---
#
# 2. Save the best model that obtains the lowest error on validation set. Wirte the code to let the best model to show the lowest error. Note that, we will use this error to create a leaderboard. **Your ranking will be used as an important prerequisite to determine your score.**
#
# ---
